# %% [markdown]
# <a href="https://colab.research.google.com/github/dimLMT/ML-assignment/blob/main/Feature_Engineering_Exercise_(Core).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
pd.set_option('display.max_columns',None)

# %%
fpath='/content/drive/MyDrive/CodingDojo/05-IntermediateML/Week17/Data/bikeshare_train - bikeshare_train.csv'
df = pd.read_csv(fpath)
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 0:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 1:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 2:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 3:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 4:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
# drop the 'casual' and 'registered' columns. These are redundant with your target, 'count'.
df = df.drop(['casual','registered'],axis=1)

# %%
# Preprocessing
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
# Define X and y
target = "count"
X = df.drop([target], axis=1).copy()
y = df[target].copy()
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42)
X_train.head()
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 2930   2011-07-11 0:00:00       3        0           1        1  28.70
# 7669  2012-05-18 22:00:00       2        0           1        1  22.96
# 1346  2011-04-01 23:00:00       2        0           1        1  12.30
# 9432   2012-09-16 9:00:00       3        0           0        1  23.78
# 453   2011-02-01 23:00:00       1        0           1        3   8.20
#
#        atemp  humidity  windspeed
# 2930  32.575        65    12.9980
# 7669  26.515        52    22.0028
# 1346  15.910        61     6.0032
# 9432  27.275        60     8.9981
# 453    9.850        93    12.9980

# %%
#Transform the 'datetime' column into a datetime type
df['datetime'].dtypes
# Out:
# dtype('O')

# %%
df['datetime']=pd.to_datetime(df['datetime'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   count       10886 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(6)
# memory usage: 850.6 KB

# %%
df['month']=df['datetime'].dt.month_name()
df['day']=df['datetime'].dt.day_name()
df['hour']=df['datetime'].dt.hour
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  count    month       day  hour
# 0        81        0.0     16  January  Saturday     0
# 1        80        0.0     40  January  Saturday     1
# 2        80        0.0     32  January  Saturday     2
# 3        75        0.0     13  January  Saturday     3
# 4        75        0.0      1  January  Saturday     4

# %%
#Drop the 'datetime' and 'season' columns. These are now redundant.
df = df.drop(['datetime','season'],axis=1)

# %%
#convert the temperatures in the 'temp' and 'atemp' columns to Fahrenheit.
df['temp']=df['temp'].apply(lambda x: 9/5*x+32)
df['atemp']=df['atemp'].apply(lambda x: 9/5*x+32)
df.head()
# Out:
#    holiday  workingday  weather    temp   atemp  humidity  windspeed  count  \
# 0        0           0        1  49.712  57.911        81        0.0     16
# 1        0           0        1  48.236  56.543        80        0.0     40
# 2        0           0        1  48.236  56.543        80        0.0     32
# 3        0           0        1  49.712  57.911        75        0.0     13
# 4        0           0        1  49.712  57.911        75        0.0      1
#
#      month       day  hour
# 0  January  Saturday     0
# 1  January  Saturday     1
# 2  January  Saturday     2
# 3  January  Saturday     3
# 4  January  Saturday     4

# %%
# Create a new column,
df['temp_variance']=df['temp']-df['atemp']
df = df.drop(['atemp'],axis=1)
df.head()
# Out:
#    holiday  workingday  weather    temp  humidity  windspeed  count    month  \
# 0        0           0        1  49.712        81        0.0     16  January
# 1        0           0        1  48.236        80        0.0     40  January
# 2        0           0        1  48.236        80        0.0     32  January
# 3        0           0        1  49.712        75        0.0     13  January
# 4        0           0        1  49.712        75        0.0      1  January
#
#         day  hour  temp_variance
# 0  Saturday     0         -8.199
# 1  Saturday     1         -8.307
# 2  Saturday     2         -8.307
# 3  Saturday     3         -8.199
# 4  Saturday     4         -8.199

# %%
# Define new X and y
target = "count"
nX = df.drop([target], axis=1)
ny = df[target]
nX_train,nX_test,ny_train,ny_test = train_test_split(nX,ny,random_state=42)
nX_train.head()
# Out:
#       holiday  workingday  weather    temp  humidity  windspeed      month  \
# 2930        0           1        1  83.660        65    12.9980       July
# 7669        0           1        1  73.328        52    22.0028        May
# 1346        0           1        1  54.140        61     6.0032      April
# 9432        0           0        1  74.804        60     8.9981  September
# 453         0           1        3  46.760        93    12.9980   February
#
#           day  hour  temp_variance
# 2930   Monday     0         -6.975
# 7669   Friday    22         -6.399
# 1346   Friday    23         -6.498
# 9432   Sunday     9         -6.291
# 453   Tuesday    23         -2.970

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
# the custom evaluation function to get the metrics for your model
def regression_metrics(y_true, y_pred, label='', verbose = True, output_dict=False):
  # Get metrics
  mae = mean_absolute_error(y_true, y_pred)
  mse = mean_squared_error(y_true, y_pred)
  rmse = mean_squared_error(y_true, y_pred, squared=False)
  r_squared = r2_score(y_true, y_pred)
  if verbose == True:
    # Print Result with Label and Header
    header = "-"*60
    print(header, f"Regression Metrics: {label}", header, sep='\n')
    print(f"- MAE = {mae:,.3f}")
    print(f"- MSE = {mse:,.3f}")
    print(f"- RMSE = {rmse:,.3f}")
    print(f"- R^2 = {r_squared:,.3f}")
  if output_dict == True:
      metrics = {'Label':label, 'MAE':mae,
                 'MSE':mse, 'RMSE':rmse, 'R^2':r_squared}
      return metrics

def evaluate_regression(reg, X_train, y_train, X_test, y_test, verbose = True,
                        output_frame=False):
  # Get predictions for training data
  y_train_pred = reg.predict(X_train)

  # Call the helper function to obtain regression metrics for training data
  results_train = regression_metrics(y_train, y_train_pred, verbose = verbose,
                                     output_dict=output_frame,
                                     label='Training Data')
  # Get predictions for test data
  y_test_pred = reg.predict(X_test)
  # Call the helper function to obtain regression metrics for test data
  results_test = regression_metrics(y_test, y_test_pred, verbose = verbose,
                                  output_dict=output_frame,
                                    label='Test Data' )

  # Store results in a dataframe if ouput_frame is True
  if output_frame:
    results_df = pd.DataFrame([results_train,results_test])
    # Set the label as the index
    results_df = results_df.set_index('Label')
    # Set index.name to none to get a cleaner looking result
    results_df.index.name=None
    # Return the dataframe
    return results_df.round(3)

# %%
#for the original features

# %%
# Instantiate a linear regression model
linreg = LinearRegression()

# %%
#for the engineered features
